# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# inporting data into the dataframe
CURBSIDE_lob_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/TOTAL_CMU_CURBSIDE_PGH_SOUTH_LOB.csv", low_memory=False)
SEGMENTATION_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/VALUE_SEGMENTATION.csv", low_memory=False)

# %%
# inporting data into the dataframe
CURBSIDE_DELIVERY_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/CURBSIDE_DELIVERY_HHS_PGH_SOUTH.csv", low_memory=False)
CURBSIDE_PICKUP_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/CURBSIDE_PICKUP_HHS_PGH_SOUTH.csv", low_memory=False)
NON_CURB_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/NON_CURB_TRANS_STORE_PGH_SOUTH.csv", low_memory=False)
Acxiom_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/Acxiom_demo_2019_recode_hh_no.csv", low_memory=False)

# %%
# inporting data into the dataframe
CURB_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/CURBSIDE_TRANS_STORE_PGH_SOUTH.csv")
CLOSEST_STORE_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/CURBSIDE_CLOSEST_STORE_PGH_SOUTH.csv")
Stores_df = pd.read_excel("/content/drive/My Drive/Giant Eagle/03_Input Data/Pittsburgh South Stores.xlsx")

# %%
# Household demographics dataframe modification
# Number of childern and adults buckets creation
Acxiom_df['Children_0_5'] = Acxiom_df[['Child_male_00_02','Child_female_00_02','Child_unknown_gender_00_02','Child_male_03_05','Child_female_03_05','Child_unknown_gender_03_05']].sum(axis='columns')
Acxiom_df['Children_6_10'] = Acxiom_df[['Child_male_06_10','Child_female_06_10','Child_unknown_gender_06_10']].sum(axis='columns')
Acxiom_df['Children_11_17'] = Acxiom_df[['Child_male_11_15','Child_female_11_15','Child_unknown_gender_11_15','Child_male_16_17','Child_female_16_17','Child_unknown_gender_16_17']].sum(axis='columns')
Acxiom_df['Adult_18_34'] = Acxiom_df[['Adult_Male_18_24','Adult_Female_18_24','Adult_Unknown_gender_18_24','Adult_Male_25_34','Adult_Female_25_34','Adult_Unknown_gender_25_34']].sum(axis='columns')
Acxiom_df['Adult_35_64'] = Acxiom_df[['Adult_Male_35_44','Adult_Female_35_44','Adult_Unknown_gender_35_44','Adult_Male_45_54','Adult_Female_45_54','Adult_Unknown_gender_45_54','Adult_Male_55_64','Adult_Female_55_64','Adult_Unknown_gender_55_64']].sum(axis='columns')
Acxiom_df['Adult_65_75plus'] = Acxiom_df[['Adult_Male_65_74','Adult_Female_65_74','Adult_Unknown_gender_65_74','Adult_Male_75plus','Adult_Female_75plus','Adult_Unknown_gender_75plus']].sum(axis='columns')
# Strip zeros for household number
Acxiom_df.HSHLD_NO = Acxiom_df['HSHLD_NO'].apply(lambda x:x.lstrip('0'))
# filter only required columns from the entire dataframe
Acxiom1_df = Acxiom_df.filter(['HSHLD_NO','Children_0_5','Children_6_10','Children_11_17','Adult_18_34','Adult_35_64','Adult_65_75plus','hh_income_p','Vehicle_Known_Owned_Num','Age_1st_Individual','Occupation_input_Indiv','Education_1st_Indiv','Ethnicity'], axis=1)

# %%
Acxiom1_df.head()
# Out:
#   HSHLD_NO  Children_0_5  ...  Education_1st_Indiv  Ethnicity
# 0        1             0  ...                  NaN          K
# 1       11             1  ...                  NaN          Z
# 2       36             0  ...                  NaN          K
# 3     2920             1  ...                  1.0          K
# 4     4025             0  ...                  NaN          Z
#
# [5 rows x 13 columns]

# %%
Acxiom_df['HSHLD_NO'] = Acxiom_df['HSHLD_NO'].astype(str)

# Data transformation. 1 if household owns vehicle, 0 if it doesn't
Acxiom1_df.loc[Acxiom1_df.Vehicle_Known_Owned_Num > 0, 'Vehicle_Known_Owned_Num'] = 1
# fill 0 if the vehicle information of the household is unknown
Acxiom1_df['Vehicle_Known_Owned_Num'].fillna(0, inplace=True)
#rename the column name
Acxiom1_df.rename(columns={'Vehicle_Known_Owned_Num': 'Vehicle_Owned_0_1'}, inplace=True)
# final data from the household demographics file
Acxiom1_df.head()
# Out:
#   HSHLD_NO  Children_0_5  ...  Education_1st_Indiv  Ethnicity
# 0        1             0  ...                  NaN          K
# 1       11             1  ...                  NaN          Z
# 2       36             0  ...                  NaN          K
# 3     2920             1  ...                  1.0          K
# 4     4025             0  ...                  NaN          Z
#
# [5 rows x 13 columns]

# %%
# filter only required columns from the entire dataframe (CURBSIDE_CLOSEST_STORE_PGH_SOUTH)
CLOSEST1_STORE_df = CLOSEST_STORE_df.filter(['HSHLD_NO','STR_NO','Dist'])
# rename the column name
CLOSEST1_STORE_df.rename(columns={'STR_NO': 'NEAR_CURBSIDE_STR_NO'}, inplace=True)
# final dataframe with distance of store
CLOSEST1_STORE_df.head()
# Out:
#    HSHLD_NO  NEAR_CURBSIDE_STR_NO      Dist
# 0     19672                    70  6.856927
# 1     21404                     4  2.525955
# 2     25374                    14  0.840881
# 3     30743                     4  2.289861
# 4     31794                    73  0.899190

# %%
# shape of the dataframe and number of unique households in the dataframe
print(Acxiom1_df.shape)
print(len(Acxiom1_df['HSHLD_NO'].unique().tolist()))
# Out:
# (4026886, 13)
# 4026886

# %%
# shape of the dataframe and number of unique households in the dataframe
print(CLOSEST1_STORE_df.shape)
print(len(CLOSEST1_STORE_df['HSHLD_NO'].unique().tolist()))
# Out:
# (9413, 3)
# 9413

# %%
# strip zeros in segmentation df
SEGMENTATION_df.HSHLD_NO = SEGMENTATION_df['HSHLD_NO'].apply(lambda x:x.lstrip('0'))
# final dataframe with segmentation values
SEGMENTATION_df.head()
# Out:
#   HSHLD_NO  DIM_2_CD
# 0       11        10
# 1       70         5
# 2     2920         4
# 3     4025         4
# 4    10004         2

# %%
# shape of the dataframe and number of unique households in the dataframe

print(SEGMENTATION_df.shape)
print(len(SEGMENTATION_df['HSHLD_NO'].unique().tolist()))
# Out:
# (3802530, 2)
# 3802530

# %%
# shape of the dataframe and number of unique households in the dataframe with number of non-curbside transactions
print(NON_CURB_df.shape)
print(len(NON_CURB_df['HSHLD_NO'].unique().tolist()))
# Out:
# (956186, 3)
# 437057

# %%
# filter only the required columns from the dataframe
NON_CURB_df = NON_CURB_df.filter(['HSHLD_NO','NON_CURBSIDE_TRANS'])
# sum all the non-curbside transactions according to the household
NON_CURB1_df = NON_CURB_df.groupby(['HSHLD_NO'], as_index=False, sort=False).sum()

# %%
# final dataframe with non-curbside transactions
NON_CURB1_df.head()
# Out:
#    HSHLD_NO  NON_CURBSIDE_TRANS
# 0     10004                   1
# 1     10008                  61
# 2     10009                  12
# 3     10016                   4
# 4     10021                 102

# %%
# shape of the dataframe and number of unique households in the dataframe
print(NON_CURB1_df.shape)
print(len(NON_CURB1_df['HSHLD_NO'].unique().tolist()))
# Out:
# (437057, 2)
# 437057

# %%
# shape of the dataframe and number of unique households in the dataframe with number of curbside transactions
print(CURB_df.shape)
print(len(CURB_df['HSHLD_NO'].unique().tolist()))
# Out:
# (12422, 3)
# 10871

# %%
# filter only the required columns from the dataframe
CURB_df = CURB_df.filter(['HSHLD_NO','CURBSIDE_TRANS'])
# sum all the curbside transactions according to the household
CURB1_df = CURB_df.groupby(['HSHLD_NO'], as_index=False, sort=False).sum()

# %%
# final dataframe with non-curbside transactions
CURB1_df.head()
# Out:
#    HSHLD_NO  CURBSIDE_TRANS
# 0     19672               5
# 1     21404               7
# 2     25374               5
# 3     30743               4
# 4     31794              26

# %%
# shape of the dataframe and number of unique households in the dataframe
print(CURB1_df.shape)
print(len(CURB1_df['HSHLD_NO'].unique().tolist()))
# Out:
# (10871, 2)
# 10871

# %%
# shape of the dataframe and number of unique households in the dataframe with number of curbside deliveries
print(CURBSIDE_DELIVERY_df.shape)
print(len(CURBSIDE_DELIVERY_df['HSHLD_NO'].unique().tolist()))
# Out:
# (3636, 17)
# 3635

# %%
# filter only the required columns from the dataframe
CURBSIDE_DELIVERY_df = CURBSIDE_DELIVERY_df.filter(['HSHLD_NO','CURBSIDE_DELIVERY_PD3_FY19','CURBSIDE_DELIVERY_PD4_FY19','CURBSIDE_DELIVERY_PD5_FY19','CURBSIDE_DELIVERY_PD6_FY19','CURBSIDE_DELIVERY_PD7_FY19','CURBSIDE_DELIVERY_PD8_FY19','CURBSIDE_DELIVERY_PD9_FY19','CURBSIDE_DELIVERY_PD10_FY19','CURBSIDE_DELIVERY_PD11_FY19','CURBSIDE_DELIVERY_PD12_FY19','CURBSIDE_DELIVERY_PD1_FY20','CURBSIDE_DELIVERY_PD2_FY20'])

# %%
# Sum up deliveries from all the periods for every household
CURBSIDE_DELIVERY_df['TOTAL_CURBSIDE_DELIVERY'] = CURBSIDE_DELIVERY_df[['CURBSIDE_DELIVERY_PD3_FY19','CURBSIDE_DELIVERY_PD4_FY19','CURBSIDE_DELIVERY_PD5_FY19','CURBSIDE_DELIVERY_PD6_FY19','CURBSIDE_DELIVERY_PD7_FY19','CURBSIDE_DELIVERY_PD8_FY19','CURBSIDE_DELIVERY_PD9_FY19','CURBSIDE_DELIVERY_PD10_FY19','CURBSIDE_DELIVERY_PD11_FY19','CURBSIDE_DELIVERY_PD12_FY19','CURBSIDE_DELIVERY_PD1_FY20','CURBSIDE_DELIVERY_PD2_FY20']].sum(axis='columns')

# %%
# filter only the required columns from the dataframe
CURBSIDE_DELIVERY1_df = CURBSIDE_DELIVERY_df.filter(['HSHLD_NO','TOTAL_CURBSIDE_DELIVERY'])

# %%
# final dataframe with curbside delivery transactions
CURBSIDE_DELIVERY1_df.head()
# Out:
#    HSHLD_NO  TOTAL_CURBSIDE_DELIVERY
# 0     44896                        1
# 1     57886                        3
# 2     63338                        2
# 3     76036                       38
# 4     76106                        2

# %%
# shape of the dataframe and number of unique households in the dataframe with number of curbside pickup
print(CURBSIDE_PICKUP_df.shape)
print(len(CURBSIDE_PICKUP_df['HSHLD_NO'].unique().tolist()))
# Out:
# (9511, 17)
# 9511

# %%
# filter only the required columns from the dataframe
CURBSIDE_PICKUP_df = CURBSIDE_PICKUP_df.filter(['HSHLD_NO','CURBSIDE_PICKUP_PD3_FY19','CURBSIDE_PICKUP_PD4_FY19','CURBSIDE_PICKUP_PD5_FY19','CURBSIDE_PICKUP_PD6_FY19','CURBSIDE_PICKUP_PD7_FY19','CURBSIDE_PICKUP_PD8_FY19','CURBSIDE_PICKUP_PD9_FY19','CURBSIDE_PICKUP_PD10_FY19','CURBSIDE_PICKUP_PD11_FY19','CURBSIDE_PICKUP_PD12_FY19','CURBSIDE_PICKUP_PD1_FY20','CURBSIDE_PICKUP_PD2_FY20'])

# %%
# Sum up pickup from all the periods for every household
CURBSIDE_PICKUP_df['TOTAL_CURBSIDE_PICKUP'] = CURBSIDE_PICKUP_df[['CURBSIDE_PICKUP_PD3_FY19','CURBSIDE_PICKUP_PD4_FY19','CURBSIDE_PICKUP_PD5_FY19','CURBSIDE_PICKUP_PD6_FY19','CURBSIDE_PICKUP_PD7_FY19','CURBSIDE_PICKUP_PD8_FY19','CURBSIDE_PICKUP_PD9_FY19','CURBSIDE_PICKUP_PD10_FY19','CURBSIDE_PICKUP_PD11_FY19','CURBSIDE_PICKUP_PD12_FY19','CURBSIDE_PICKUP_PD1_FY20','CURBSIDE_PICKUP_PD2_FY20']].sum(axis='columns')

# %%
# filter only the required columns from the dataframe
CURBSIDE_PICKUP1_df = CURBSIDE_PICKUP_df.filter(['HSHLD_NO','TOTAL_CURBSIDE_PICKUP'])

# %%
# final dataframe with curbside pickup transactions
CURBSIDE_PICKUP1_df.head()
# Out:
#    HSHLD_NO  TOTAL_CURBSIDE_PICKUP
# 0     19672                      5
# 1     25374                      5
# 2     30743                      4
# 3     31794                     26
# 4     44896                      5

# %%
# shape of the dataframe and number of unique households in the dataframe with transactions at department level
print(CURBSIDE_lob_df.shape)
print(len(CURBSIDE_lob_df['HSHLD_NO'].unique().tolist()))
# Out:
# (6987307, 79)
# 305795

# %%
# Total curbside units from the LOB file (department file)
CURBSIDE_lob_df['TOTAL_CURBSIDE_UNITS'] = CURBSIDE_lob_df[['CURBSIDE_UNITS_PD3','CURBSIDE_UNITS_PD4','CURBSIDE_UNITS_PD5','CURBSIDE_UNITS_PD6','CURBSIDE_UNITS_PD7','CURBSIDE_UNITS_PD8','CURBSIDE_UNITS_PD9','CURBSIDE_UNITS_PD10','CURBSIDE_UNITS_PD11','CURBSIDE_UNITS_PD12','CURBSIDE_UNITS_PD1','CURBSIDE_UNITS_PD2']].sum(axis='columns')
# Total non-curbside units across all the departments
CURBSIDE_lob_df['TOTAL_NON_CURBSIDE_UNITS'] = CURBSIDE_lob_df[['NON_CURBSIDE_UNITS_PD3','NON_CURBSIDE_UNITS_PD4','NON_CURBSIDE_UNITS_PD5','NON_CURBSIDE_UNITS_PD6','NON_CURBSIDE_UNITS_PD7','NON_CURBSIDE_UNITS_PD8','NON_CURBSIDE_UNITS_PD9','NON_CURBSIDE_UNITS_PD10','NON_CURBSIDE_UNITS_PD11','NON_CURBSIDE_UNITS_PD12','NON_CURBSIDE_UNITS_PD1','NON_CURBSIDE_UNITS_PD2']].sum(axis='columns')
# Total spend for curbside units across all the departments
CURBSIDE_lob_df['TOTAL_CURBSIDE_SPEND'] = CURBSIDE_lob_df[['CURBSIDE_SPEND_PD3','CURBSIDE_SPEND_PD4','CURBSIDE_SPEND_PD5','CURBSIDE_SPEND_PD6','CURBSIDE_SPEND_PD7','CURBSIDE_SPEND_PD8','CURBSIDE_SPEND_PD9','CURBSIDE_SPEND_PD10','CURBSIDE_SPEND_PD11','CURBSIDE_SPEND_PD12','CURBSIDE_SPEND_PD1','CURBSIDE_SPEND_PD2']].sum(axis='columns')
# Total spend for non-curbside units across all the departments
CURBSIDE_lob_df['TOTAL_NON_CURBSIDE_SPEND'] = CURBSIDE_lob_df[['NON_CURBSIDE_SPEND_PD3','NON_CURBSIDE_SPEND_PD4','NON_CURBSIDE_SPEND_PD5','NON_CURBSIDE_SPEND_PD6','NON_CURBSIDE_SPEND_PD7','NON_CURBSIDE_SPEND_PD8','NON_CURBSIDE_SPEND_PD9','NON_CURBSIDE_SPEND_PD10','NON_CURBSIDE_SPEND_PD11','NON_CURBSIDE_SPEND_PD12','NON_CURBSIDE_SPEND_PD1','NON_CURBSIDE_SPEND_PD2']].sum(axis='columns')

# %%
# Total units = curbside + non-curbside
CURBSIDE_lob_df['TOTAL_UNITS'] = CURBSIDE_lob_df[['TOTAL_CURBSIDE_UNITS','TOTAL_NON_CURBSIDE_UNITS']].sum(axis='columns')
# total amount = curbside + non-curbside
CURBSIDE_lob_df['TOTAL_SPEND'] = CURBSIDE_lob_df[['TOTAL_CURBSIDE_SPEND', 'TOTAL_NON_CURBSIDE_SPEND']].sum(axis='columns')

# %%
# filter out all the required columns
CURBSIDE_lob_df = CURBSIDE_lob_df.filter(['HSHLD_NO','TOTAL_CURBSIDE_UNITS','TOTAL_NON_CURBSIDE_UNITS','TOTAL_CURBSIDE_SPEND','TOTAL_NON_CURBSIDE_SPEND', 'TOTAL_UNITS', 'TOTAL_SPEND'], axis=1)
# add the data if households have multiple entries
CURBSIDE1_lob_df = CURBSIDE_lob_df.groupby(['HSHLD_NO'], as_index=False, sort=False).sum()

# %%
# shape of the dataframe and number of unique households in the dataframe
print(CURBSIDE1_lob_df.shape)
print(len(CURBSIDE1_lob_df['HSHLD_NO'].unique().tolist()))
# Out:
# (305795, 7)
# 305795

# %%
# final dataframe lob 
CURBSIDE1_lob_df.head()
# Out:
#    HSHLD_NO  TOTAL_CURBSIDE_UNITS  ...  TOTAL_UNITS  TOTAL_SPEND
# 0     10008                   0.0  ...      3409.79      9722.40
# 1     10021                   0.0  ...      1551.26      4851.53
# 2     10022                   0.0  ...      1941.78      6298.35
# 3     11717                   0.0  ...        68.47       165.50
# 4     11890                   0.0  ...       412.36      1293.52
#
# [5 rows x 7 columns]

# %%
# read the file to SAMPLE_CURBSIDE_NON_CURBSIDE.csv to choose primary store for household
SAMPLE_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/SAMPLE_CURBSIDE_NON_CURBSIDE.csv", low_memory=False)

# %%
# shape of the dataframe and number of unique households in the dataframe
print(SAMPLE_df.shape)
print(len(SAMPLE_df['HSHLD_NO'].unique().tolist()))
# Out:
# (305821, 15)
# 305796

# %%
# filter to keep only the required columns
SAMPLE_df = SAMPLE_df.filter(['HSHLD_NO','STR_NO'])
# since there are only a few households repeating, keep only the first appearance of the household to choose the primary store
SAMPLE1_df = SAMPLE_df.drop_duplicates(subset='HSHLD_NO', keep="first")
# final dataframe to choose primary store numbers
SAMPLE1_df.head()
# Out:
#    HSHLD_NO  STR_NO
# 0     10008      73
# 1     10021      74
# 2     10022      74
# 3     10061       4
# 4     10620      39

# %%
# read lob file to calculate total number of departments a household shopped from 
lob_df = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/TOTAL_CMU_CURBSIDE_PGH_SOUTH_LOB.csv", low_memory=False)

# %%
# get the number of departments every household shopped from
dep_df = lob_df.groupby(by='HSHLD_NO', as_index=False).agg({'BSNS_LN_CD': pd.Series.nunique})

# %%
# rename the column name
dep_df.rename(columns={"BSNS_LN_CD": "BSNS_LN_CD_TOTAL"}, inplace=True)
# final dataframe
dep_df.head()
# Out:
#    HSHLD_NO  BSNS_LN_CD_TOTAL
# 0     10008              16.0
# 1     10021              16.0
# 2     10022              15.0
# 3     10061               2.0
# 4     10620               3.0

# %%
# Dataframe columns

#Acxiom1_df ----> HSHLD_NO	Children_0_5	Children_6_10	Children_11_17	Adult_18_34	Adult_35_64	Adult_65_75plus	hh_income_p	Vehicle_Owned_0_1	Age_1st_Individual	Occupation_input_Indiv	Education_1st_Indiv	Ethnicity
#SEGMENTATION_df------------> 'HSHLD_NO', 'DIM_2_CD'
#NON_CURB1_df ------------> 'HSHLD_NO','NON_CURBSIDE_TRANS'
#CURB1_df --------> 'HSHLD_NO','CURBSIDE_TRANS'
#CURBSIDE_DELIVERY1_df ------> 'HSHLD_NO','TOTAL_CURBSIDE_DELIVERY'
#CURBSIDE_PICKUP1_df --------> 'HSHLD_NO','TOTAL_CURBSIDE_PICKUP'
#CURBSIDE1_lob_df -------> 'HSHLD_NO','TOTAL_CURBSIDE_UNITS','TOTAL_NON_CURBSIDE_UNITS','TOTAL_CURBSIDE_SPEND','TOTAL_CURBSIDE_SPEND', 'TOTAL_UNITS', 'TOTAL_SPEND'
#CLOSEST1_STORE_df ------> HSHLD_NO	NEAR_CURBSIDE_STR_NO	Dist
#SAMPLE1_df ----> 'HSHLD_NO','STR_NO'
#dep_df -----> HSHLD_NO	BSNS_LN_CD_TOTAL

# merging dataframes
result = pd.merge(CURBSIDE1_lob_df,
                 NON_CURB1_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result = pd.merge(result,
                 CURB1_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result = pd.merge(result,
                 CURBSIDE_DELIVERY1_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result = pd.merge(result,
                 CURBSIDE_PICKUP1_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result = pd.merge(result,
                 CLOSEST1_STORE_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result = pd.merge(result,
                 SAMPLE1_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result = pd.merge(result,
                 dep_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result.head()
# Out:
#    HSHLD_NO  TOTAL_CURBSIDE_UNITS  ...  STR_NO  BSNS_LN_CD_TOTAL
# 0     10008                   0.0  ...      73              16.0
# 1     10021                   0.0  ...      74              16.0
# 2     10022                   0.0  ...      74              15.0
# 3     11717                   0.0  ...      70               7.0
# 4     11890                   0.0  ...      53              11.0
#
# [5 rows x 15 columns]

# %%
# reading LOB file
lob = pd.read_csv("/content/drive/My Drive/Giant Eagle/03_Input Data/TOTAL_CMU_CURBSIDE_PGH_SOUTH_LOB.csv", low_memory = False)

# %%
# Separating columns that can't be used in the grouping function (generally columns with string values) into another dataframe
unused_for_grouping = lob[["HSHLD_NO", "POS_DPT_CD",	"POS_DPT_DSCR", "BSNS_LN_CD", "BSNS_LN_DSCR", "STR_NO", "PRIMARY_SPEND"]]

# %%
# Create a dataframe to group the data based on Household & Business Line.
used_for_grouping= lob[["HSHLD_NO", "POS_DPT_DSCR", "NON_CURBSIDE_TRANS_PD3",	"NON_CURBSIDE_SPEND_PD3",	"NON_CURBSIDE_UNITS_PD3",	"CURBSIDE_TRANS_PD3",	"CURBSIDE_SPEND_PD3",	"CURBSIDE_UNITS_PD3",	"NON_CURBSIDE_TRANS_PD4",	"NON_CURBSIDE_SPEND_PD4",	"NON_CURBSIDE_UNITS_PD4",	"CURBSIDE_TRANS_PD4",	"CURBSIDE_SPEND_PD4",	"CURBSIDE_UNITS_PD4",	"NON_CURBSIDE_TRANS_PD5",	"NON_CURBSIDE_SPEND_PD5",	"NON_CURBSIDE_UNITS_PD5",	"CURBSIDE_TRANS_PD5",	"CURBSIDE_SPEND_PD5",	"CURBSIDE_UNITS_PD5",	"NON_CURBSIDE_TRANS_PD6",	"NON_CURBSIDE_SPEND_PD6",	"NON_CURBSIDE_UNITS_PD6",	"CURBSIDE_TRANS_PD6",	"CURBSIDE_SPEND_PD6",	"CURBSIDE_UNITS_PD6",	"NON_CURBSIDE_TRANS_PD7",	"NON_CURBSIDE_SPEND_PD7",	"NON_CURBSIDE_UNITS_PD7",	"CURBSIDE_TRANS_PD7",	"CURBSIDE_SPEND_PD7",	"CURBSIDE_UNITS_PD7",	"NON_CURBSIDE_TRANS_PD8",	"NON_CURBSIDE_SPEND_PD8",	"NON_CURBSIDE_UNITS_PD8",	"CURBSIDE_TRANS_PD8",	"CURBSIDE_SPEND_PD8",	"CURBSIDE_UNITS_PD8",	"NON_CURBSIDE_TRANS_PD9",	"NON_CURBSIDE_SPEND_PD9",	"NON_CURBSIDE_UNITS_PD9",	"CURBSIDE_TRANS_PD9",	"CURBSIDE_SPEND_PD9",	"CURBSIDE_UNITS_PD9",	"NON_CURBSIDE_TRANS_PD10",	"NON_CURBSIDE_SPEND_PD10",	"NON_CURBSIDE_UNITS_PD10",	"CURBSIDE_TRANS_PD10",	"CURBSIDE_SPEND_PD10",	"CURBSIDE_UNITS_PD10",	"NON_CURBSIDE_TRANS_PD11",	"NON_CURBSIDE_SPEND_PD11",	"NON_CURBSIDE_UNITS_PD11",	"CURBSIDE_TRANS_PD11",	"CURBSIDE_SPEND_PD11",	"CURBSIDE_UNITS_PD11",	"NON_CURBSIDE_TRANS_PD12",	"NON_CURBSIDE_SPEND_PD12",	"NON_CURBSIDE_UNITS_PD12",	"CURBSIDE_TRANS_PD12",	"CURBSIDE_SPEND_PD12",	"CURBSIDE_UNITS_PD12",	"NON_CURBSIDE_TRANS_PD1",	"NON_CURBSIDE_SPEND_PD1",	"NON_CURBSIDE_UNITS_PD1",	"CURBSIDE_TRANS_PD1",	"CURBSIDE_SPEND_PD1",	"CURBSIDE_UNITS_PD1",	"NON_CURBSIDE_TRANS_PD2",	"NON_CURBSIDE_SPEND_PD2",	"NON_CURBSIDE_UNITS_PD2",	"CURBSIDE_TRANS_PD2",	"CURBSIDE_SPEND_PD2",	"CURBSIDE_UNITS_PD2"]]
used_for_grouping = used_for_grouping.groupby(["HSHLD_NO", "POS_DPT_DSCR"]).sum()

# %%
# Summing up all the period-wise (PD1 to PD12) Non-Curbside & Curbside: Spend, Transaction & Units columns into a single yearly column
used_for_grouping['NON_CURBSIDE_SPEND_TOTAL'] = used_for_grouping['NON_CURBSIDE_SPEND_PD1'] + used_for_grouping['NON_CURBSIDE_SPEND_PD2'] + used_for_grouping['NON_CURBSIDE_SPEND_PD3'] + used_for_grouping['NON_CURBSIDE_SPEND_PD4'] + used_for_grouping['NON_CURBSIDE_SPEND_PD5'] + used_for_grouping['NON_CURBSIDE_SPEND_PD6'] + used_for_grouping['NON_CURBSIDE_SPEND_PD7'] + used_for_grouping['NON_CURBSIDE_SPEND_PD8'] + used_for_grouping['NON_CURBSIDE_SPEND_PD9'] + used_for_grouping['NON_CURBSIDE_SPEND_PD10']

# %%
used_for_grouping['CURBSIDE_SPEND_TOTAL'] = used_for_grouping['CURBSIDE_SPEND_PD1'] + used_for_grouping['CURBSIDE_SPEND_PD2'] + used_for_grouping['CURBSIDE_SPEND_PD3'] + used_for_grouping['CURBSIDE_SPEND_PD4'] + used_for_grouping['CURBSIDE_SPEND_PD5'] + used_for_grouping['CURBSIDE_SPEND_PD6'] + used_for_grouping['CURBSIDE_SPEND_PD7'] + used_for_grouping['CURBSIDE_SPEND_PD8'] + used_for_grouping['CURBSIDE_SPEND_PD9'] + used_for_grouping['CURBSIDE_SPEND_PD10']

# %%
used_for_grouping['NON_CURBSIDE_TRANS_TOTAL'] = used_for_grouping['NON_CURBSIDE_TRANS_PD1'] + used_for_grouping['NON_CURBSIDE_TRANS_PD2'] + used_for_grouping['NON_CURBSIDE_TRANS_PD3'] + used_for_grouping['NON_CURBSIDE_TRANS_PD4'] + used_for_grouping['NON_CURBSIDE_TRANS_PD5'] + used_for_grouping['NON_CURBSIDE_TRANS_PD6'] + used_for_grouping['NON_CURBSIDE_TRANS_PD7'] + used_for_grouping['NON_CURBSIDE_TRANS_PD8'] +used_for_grouping['NON_CURBSIDE_TRANS_PD9'] +used_for_grouping['NON_CURBSIDE_TRANS_PD10'] +used_for_grouping['NON_CURBSIDE_TRANS_PD11'] +used_for_grouping['NON_CURBSIDE_TRANS_PD12']

# %%
used_for_grouping['CURBSIDE_TRANS_TOTAL'] =  used_for_grouping['CURBSIDE_TRANS_PD1'] + used_for_grouping['CURBSIDE_TRANS_PD2'] + used_for_grouping['CURBSIDE_TRANS_PD3'] + used_for_grouping['CURBSIDE_TRANS_PD4'] + used_for_grouping['CURBSIDE_TRANS_PD5'] + used_for_grouping['CURBSIDE_TRANS_PD6'] + used_for_grouping['CURBSIDE_TRANS_PD7'] + used_for_grouping['CURBSIDE_TRANS_PD8'] +used_for_grouping['CURBSIDE_TRANS_PD9'] +used_for_grouping['CURBSIDE_TRANS_PD10'] +used_for_grouping['CURBSIDE_TRANS_PD11'] +used_for_grouping['CURBSIDE_TRANS_PD12']

# %%
used_for_grouping['NON_CURBSIDE_UNITS_TOTAL'] = used_for_grouping['NON_CURBSIDE_UNITS_PD1'] + used_for_grouping['NON_CURBSIDE_UNITS_PD2'] + used_for_grouping['NON_CURBSIDE_UNITS_PD3'] + used_for_grouping['NON_CURBSIDE_UNITS_PD4'] + used_for_grouping['NON_CURBSIDE_UNITS_PD5'] + used_for_grouping['NON_CURBSIDE_UNITS_PD6'] + used_for_grouping['NON_CURBSIDE_UNITS_PD7'] + used_for_grouping['NON_CURBSIDE_UNITS_PD8'] +used_for_grouping['NON_CURBSIDE_UNITS_PD9'] +used_for_grouping['NON_CURBSIDE_UNITS_PD10'] +used_for_grouping['NON_CURBSIDE_UNITS_PD11'] +used_for_grouping['NON_CURBSIDE_UNITS_PD12']

# %%
used_for_grouping['CURBSIDE_UNITS_TOTAL'] = used_for_grouping['CURBSIDE_UNITS_PD1'] + used_for_grouping['CURBSIDE_UNITS_PD2'] + used_for_grouping['CURBSIDE_UNITS_PD3'] + used_for_grouping['CURBSIDE_UNITS_PD4'] + used_for_grouping['CURBSIDE_UNITS_PD5'] + used_for_grouping['CURBSIDE_UNITS_PD6'] + used_for_grouping['CURBSIDE_UNITS_PD7'] + used_for_grouping['CURBSIDE_UNITS_PD8'] +used_for_grouping['CURBSIDE_UNITS_PD9'] +used_for_grouping['CURBSIDE_UNITS_PD10'] +used_for_grouping['CURBSIDE_UNITS_PD11'] +used_for_grouping['CURBSIDE_UNITS_PD12']

# %%
#Dropping all the period-wise (PD1 to PD12) Non-Curbside & Curbside: Spend, Transaction & Units columns from the dataframe
used_for_grouping.drop(['NON_CURBSIDE_SPEND_PD1', 'CURBSIDE_SPEND_PD1', 'NON_CURBSIDE_TRANS_PD1', 'CURBSIDE_TRANS_PD1', 'NON_CURBSIDE_UNITS_PD1', 'CURBSIDE_UNITS_PD1', 'NON_CURBSIDE_SPEND_PD2', 'CURBSIDE_SPEND_PD2', 'NON_CURBSIDE_TRANS_PD2', 'CURBSIDE_TRANS_PD2', 'NON_CURBSIDE_UNITS_PD2', 'CURBSIDE_UNITS_PD2',
'NON_CURBSIDE_SPEND_PD3', 'CURBSIDE_SPEND_PD3', 'NON_CURBSIDE_TRANS_PD3', 'CURBSIDE_TRANS_PD3', 'NON_CURBSIDE_UNITS_PD3', 'CURBSIDE_UNITS_PD3',
'NON_CURBSIDE_SPEND_PD4', 'CURBSIDE_SPEND_PD4', 'NON_CURBSIDE_TRANS_PD4', 'CURBSIDE_TRANS_PD4', 'NON_CURBSIDE_UNITS_PD4', 'CURBSIDE_UNITS_PD4',
'NON_CURBSIDE_SPEND_PD5', 'CURBSIDE_SPEND_PD5', 'NON_CURBSIDE_TRANS_PD5', 'CURBSIDE_TRANS_PD5', 'NON_CURBSIDE_UNITS_PD5', 'CURBSIDE_UNITS_PD5',
'NON_CURBSIDE_SPEND_PD6', 'CURBSIDE_SPEND_PD6', 'NON_CURBSIDE_TRANS_PD6', 'CURBSIDE_TRANS_PD6', 'NON_CURBSIDE_UNITS_PD6', 'CURBSIDE_UNITS_PD6',
'NON_CURBSIDE_SPEND_PD7', 'CURBSIDE_SPEND_PD7', 'NON_CURBSIDE_TRANS_PD7', 'CURBSIDE_TRANS_PD7', 'NON_CURBSIDE_UNITS_PD7', 'CURBSIDE_UNITS_PD7',
'NON_CURBSIDE_SPEND_PD8', 'CURBSIDE_SPEND_PD8', 'NON_CURBSIDE_TRANS_PD8', 'CURBSIDE_TRANS_PD8', 'NON_CURBSIDE_UNITS_PD8', 'CURBSIDE_UNITS_PD8',
'NON_CURBSIDE_SPEND_PD9', 'CURBSIDE_SPEND_PD9', 'NON_CURBSIDE_TRANS_PD9', 'CURBSIDE_TRANS_PD9', 'NON_CURBSIDE_UNITS_PD9', 'CURBSIDE_UNITS_PD9',
'NON_CURBSIDE_SPEND_PD10', 'CURBSIDE_SPEND_PD10', 'NON_CURBSIDE_TRANS_PD10', 'CURBSIDE_TRANS_PD10', 'NON_CURBSIDE_UNITS_PD10', 'CURBSIDE_UNITS_PD10',
'NON_CURBSIDE_SPEND_PD11', 'CURBSIDE_SPEND_PD11', 'NON_CURBSIDE_TRANS_PD11', 'CURBSIDE_TRANS_PD11', 'NON_CURBSIDE_UNITS_PD11', 'CURBSIDE_UNITS_PD11',
'NON_CURBSIDE_SPEND_PD12', 'CURBSIDE_SPEND_PD12', 'NON_CURBSIDE_TRANS_PD12', 'CURBSIDE_TRANS_PD12', 'NON_CURBSIDE_UNITS_PD12', 'CURBSIDE_UNITS_PD12',], axis=1, inplace=True)

# %%
# Pivot the dataframe to obtain Categories as columns for every TOTAL Non-Curbside & Curbside: Spend, Transaction & Units column.
pivoted = used_for_grouping.pivot_table(['NON_CURBSIDE_SPEND_TOTAL', 'CURBSIDE_SPEND_TOTAL', 'NON_CURBSIDE_TRANS_TOTAL', 'CURBSIDE_TRANS_TOTAL', 'NON_CURBSIDE_UNITS_TOTAL', 'CURBSIDE_UNITS_TOTAL'], ['HSHLD_NO'], 'POS_DPT_DSCR')

# %%
# Replace all NaN values with -1
# Reason:
# A category which has never had any transaction/spend/units with a particular household will be identified by "-1"
# A category that may have had at least one transaction/spend/units with a particular household will be identified by "0"
pivoted.fillna(0)
# Out:
#              CURBSIDE_SPEND_TOTAL                      ... NON_CURBSIDE_UNITS_TOTAL
# POS_DPT_DSCR   Alternative Snacks Automotive Products  ...              Video Sales Wine
# HSHLD_NO                                               ...
# 10008                         0.0                 0.0  ...                      0.0  0.0
# 10021                         0.0                 0.0  ...                      0.0  0.0
# 10022                         0.0                 0.0  ...                      0.0  0.0
# 10061                         0.0                 0.0  ...                      0.0  0.0
# 10620                         0.0                 0.0  ...                      0.0  0.0
# ...                           ...                 ...  ...                      ...  ...
# 92070929                      0.0                 0.0  ...                      0.0  0.0
# 92071086                      0.0                 0.0  ...                      0.0  0.0
# ...

# %%
result = pd.merge(result,
                 pivoted,
                 on='HSHLD_NO', 
                 how='left')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)

# %%
result['HSHLD_NO'] = result['HSHLD_NO'].astype(str)
SEGMENTATION_df['HSHLD_NO'] = SEGMENTATION_df['HSHLD_NO'].astype(str)
Acxiom1_df['HSHLD_NO'] = Acxiom1_df['HSHLD_NO'].astype(str)

# %%
result = pd.merge(result,
                 SEGMENTATION_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result = pd.merge(result,
                 Acxiom1_df,
                 on='HSHLD_NO', 
                 how='left')

# %%
result.head()
# Out:
#   HSHLD_NO  TOTAL_CURBSIDE_UNITS  ...  Education_1st_Indiv  Ethnicity
# 0    10008                   0.0  ...                  3.0          K
# 1    10021                   0.0  ...                  1.0          K
# 2    10022                   0.0  ...                  3.0          L
# 3    11717                   0.0  ...                  NaN          A
# 4    11890                   0.0  ...                  1.0          K
#
# [5 rows x 646 columns]

# %%
for c in result.columns:
  print(c)
# Out:
# HSHLD_NO
# TOTAL_CURBSIDE_UNITS
# TOTAL_NON_CURBSIDE_UNITS
# TOTAL_CURBSIDE_SPEND
# TOTAL_NON_CURBSIDE_SPEND
# TOTAL_UNITS
# TOTAL_SPEND
# NON_CURBSIDE_TRANS
# CURBSIDE_TRANS
# TOTAL_CURBSIDE_DELIVERY
# TOTAL_CURBSIDE_PICKUP
# NEAR_CURBSIDE_STR_NO
# Dist
# STR_NO
# BSNS_LN_CD_TOTAL
# ('CURBSIDE_SPEND_TOTAL', 'Alternative Snacks')
# ('CURBSIDE_SPEND_TOTAL', 'Automotive Products')
# ('CURBSIDE_SPEND_TOTAL', 'Baby')
# ('CURBSIDE_SPEND_TOTAL', 'Bagels')
# ('CURBSIDE_SPEND_TOTAL', 'Bakery Confectionary')
# ('CURBSIDE_SPEND_TOTAL', 'Beauty')
# ('CURBSIDE_SPEND_TOTAL', 'Beer')
# ('CURBSIDE_SPEND_TOTAL', 'Books')
# ('CURBSIDE_SPEND_TOTAL', 'Breads')
# ('CURBSIDE_SPEND_TOTAL', 'Breakfast Baking')
# ('CURBSIDE_SPEND_TOTAL', 'Cafe')
# ('CURBSIDE_SPEND_TOTAL', 'Cakes')
# ('CURBSIDE_SPEND_TOTAL', 'Candy')
# ('CURBSIDE_SPEND_TOTAL', 'Charcuterie')
# ('CURBSIDE_SPEND_TOTAL', 'Cheese Shop')
# ('CURBSIDE_SPEND_TOTAL', 'Cigarettes')
# ('CURBSIDE_SPEND_TOTAL', 'Coffee Kiosk')
# ...

# %%
del Acxiom1_df
del SEGMENTATION_df
del NON_CURB1_df
del CURB1_df
del CURBSIDE_DELIVERY1_df
del CURBSIDE_PICKUP1_df
del CURBSIDE1_lob_df
del CLOSEST1_STORE_df
del SAMPLE1_df
del dep_df

# %%
#Dropping distance column because 98% data is null
result.drop(columns=['Dist'], inplace=True)

# %%
# Filling all curbside spend total, curbside units total and curbside trans total in each category to 0
cst = [c for c in result.columns if 'CURBSIDE_SPEND_TOTAL' in c]
cut = [c for c in result.columns if 'CURBSIDE_UNITS_TOTAL' in c]
ctt = [c for c in result.columns if 'CURBSIDE_TRANS_TOTAL' in c]

# %%
for c in cst:
  result[c].fillna(0, inplace=True)
  result[c] = result[c].apply(lambda x:0 if x<0 else x)
for c in cut:
  result[c].fillna(0, inplace=True)
  result[c] = result[c].apply(lambda x:0 if x<0 else x)
for c in ctt:
  result[c].fillna(0, inplace=True)
  result[c] = result[c].apply(lambda x:0 if x<0 else x)

# %%
for c in result.columns:
  print(c)
# Out:
# HSHLD_NO
# TOTAL_CURBSIDE_UNITS
# TOTAL_NON_CURBSIDE_UNITS
# TOTAL_CURBSIDE_SPEND
# TOTAL_NON_CURBSIDE_SPEND
# TOTAL_UNITS
# TOTAL_SPEND
# NON_CURBSIDE_TRANS
# CURBSIDE_TRANS
# TOTAL_CURBSIDE_DELIVERY
# TOTAL_CURBSIDE_PICKUP
# NEAR_CURBSIDE_STR_NO
# STR_NO
# BSNS_LN_CD_TOTAL
# ('CURBSIDE_SPEND_TOTAL', 'Alternative Snacks')
# ('CURBSIDE_SPEND_TOTAL', 'Automotive Products')
# ('CURBSIDE_SPEND_TOTAL', 'Baby')
# ('CURBSIDE_SPEND_TOTAL', 'Bagels')
# ('CURBSIDE_SPEND_TOTAL', 'Bakery Confectionary')
# ('CURBSIDE_SPEND_TOTAL', 'Beauty')
# ('CURBSIDE_SPEND_TOTAL', 'Beer')
# ('CURBSIDE_SPEND_TOTAL', 'Books')
# ('CURBSIDE_SPEND_TOTAL', 'Breads')
# ('CURBSIDE_SPEND_TOTAL', 'Breakfast Baking')
# ('CURBSIDE_SPEND_TOTAL', 'Cafe')
# ('CURBSIDE_SPEND_TOTAL', 'Cakes')
# ('CURBSIDE_SPEND_TOTAL', 'Candy')
# ('CURBSIDE_SPEND_TOTAL', 'Charcuterie')
# ('CURBSIDE_SPEND_TOTAL', 'Cheese Shop')
# ('CURBSIDE_SPEND_TOTAL', 'Cigarettes')
# ('CURBSIDE_SPEND_TOTAL', 'Coffee Kiosk')
# ...

# %%
curbside_total_columns = ["('CURBSIDE_SPEND_TOTAL', 'Bakery')", "('CURBSIDE_SPEND_TOTAL', 'Beer Wine Liquor')", "('CURBSIDE_SPEND_TOTAL', 'Books & Magazines')", "('CURBSIDE_SPEND_TOTAL', 'Candy')", "('CURBSIDE_SPEND_TOTAL', 'Cigarettes')", "('CURBSIDE_SPEND_TOTAL', 'Dairy')", "('CURBSIDE_SPEND_TOTAL', 'Deli')", "('CURBSIDE_SPEND_TOTAL', 'Floral')", "('CURBSIDE_SPEND_TOTAL', 'Frozen')", "('CURBSIDE_SPEND_TOTAL', 'General Merchandise')", "('CURBSIDE_SPEND_TOTAL', 'Greeting Cards')", "('CURBSIDE_SPEND_TOTAL', 'Grocery Edible')", "('CURBSIDE_SPEND_TOTAL', 'Grocery Inedible')", "('CURBSIDE_SPEND_TOTAL', 'HBC')", "('CURBSIDE_SPEND_TOTAL', 'Meat')", "('CURBSIDE_SPEND_TOTAL', 'Miscellaneous')", "('CURBSIDE_SPEND_TOTAL', 'Photo')", "('CURBSIDE_SPEND_TOTAL', 'Prepared Foods')", "('CURBSIDE_SPEND_TOTAL', 'Produce')", "('CURBSIDE_SPEND_TOTAL', 'Seafood')", "('CURBSIDE_SPEND_TOTAL', 'Tobacco')", "('CURBSIDE_SPEND_TOTAL', 'Video')"]
non_curbside_total_columns = ["('NON_CURBSIDE_SPEND_TOTAL', 'Bakery')", "('NON_CURBSIDE_SPEND_TOTAL', 'Beer Wine Liquor')", "('NON_CURBSIDE_SPEND_TOTAL', 'Books & Magazines')", "('NON_CURBSIDE_SPEND_TOTAL', 'Candy')", "('NON_CURBSIDE_SPEND_TOTAL', 'Cigarettes')", "('NON_CURBSIDE_SPEND_TOTAL', 'Dairy')", "('NON_CURBSIDE_SPEND_TOTAL', 'Deli')", "('NON_CURBSIDE_SPEND_TOTAL', 'Floral')", "('NON_CURBSIDE_SPEND_TOTAL', 'Frozen')", "('NON_CURBSIDE_SPEND_TOTAL', 'General Merchandise')", "('NON_CURBSIDE_SPEND_TOTAL', 'Greeting Cards')", "('NON_CURBSIDE_SPEND_TOTAL', 'Grocery Edible')", "('NON_CURBSIDE_SPEND_TOTAL', 'Grocery Inedible')", "('NON_CURBSIDE_SPEND_TOTAL', 'HBC')", "('NON_CURBSIDE_SPEND_TOTAL', 'Meat')", "('NON_CURBSIDE_SPEND_TOTAL', 'Miscellaneous')", "('NON_CURBSIDE_SPEND_TOTAL', 'Photo')", "('NON_CURBSIDE_SPEND_TOTAL', 'Prepared Foods')", "('NON_CURBSIDE_SPEND_TOTAL', 'Produce')", "('NON_CURBSIDE_SPEND_TOTAL', 'Seafood')", "('NON_CURBSIDE_SPEND_TOTAL', 'Tobacco')", "('NON_CURBSIDE_SPEND_TOTAL', 'Video')"]

result['TOTAL_CURBSIDE_SPEND'] = result[curbside_total_columns].sum(axis="columns")
result['TOTAL_NON_CURBSIDE_SPEND'] = result[non_curbside_total_columns].sum(axis="columns")

result.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-263-e7754300e9ee> in <module>()
# ...

# %%
result.Children_0_5.fillna(0, inplace=True)
result.Children_6_10.fillna(0, inplace=True)
result.Children_11_17.fillna(0, inplace=True)
result.Adult_18_34.fillna(0, inplace=True)
result.Adult_35_64.fillna(0, inplace=True)
result.Adult_65_75plus.fillna(0, inplace=True)

# %%
#categorize HH_Income_M into 4 categories. Variable name 'Income_Buckets'
#1 HH_Income_M <=30000 "1_Lower_Class"
#2 HH_Income_M >30000 & <=65000 "2_Lower_Middle_Class"
#3 HH_Income_M >65000 & <=100000 "3_Upper_Middle_Class"
#4 HH_Income_M >100000 "4_Upper_Class"

# %%
result['Income_Buckets'] = result['HH_Income_M']

# %%
result['Income_Buckets'] = result['Income_Buckets'].apply(lambda x: 1
                                                            if (x<=30000 and x>0) 
                                                            else (2 if (x<=65000 and x>30000) 
                                                                    else (3 if (x<=100000.0 and x>65000) 
                                                                            else (4 if (x>100000) else x))))

# %%
result['TOTAL_CURBSIDE_UNITS'].fillna(0, inplace=True)
result['TOTAL_NON_CURBSIDE_UNITS'].fillna(0, inplace=True)
result['TOTAL_CURBSIDE_SPEND'].fillna(0, inplace=True)
result['TOTAL_NON_CURBSIDE_SPEND'].fillna(0, inplace=True)
result['TOTAL_UNITS'].fillna(0, inplace=True)
result['TOTAL_SPEND'].fillna(0, inplace=True)
result['TOTAL_CURBSIDE_UNITS'].fillna(0, inplace=True)
result['NON_CURBSIDE_TRANS'].fillna(0, inplace=True)
result['CURBSIDE_TRANS'].fillna(0, inplace=True)
result['TOTAL_CURBSIDE_PICKUP'].fillna(0, inplace=True)
result['TOTAL_CURBSIDE_DELIVERY'].fillna(0, inplace=True)

# %%
result.head()

# %%
result['CURBSIDE_PICKUP_%'] = result['TOTAL_CURBSIDE_PICKUP'].divide(result['TOTAL_CURBSIDE_PICKUP']+result['TOTAL_CURBSIDE_DELIVERY'])
result['CURBSIDE_PICKUP_%'].fillna(0, inplace=True)
result['CURBSIDE_DELIVERY_%'] = result['TOTAL_CURBSIDE_DELIVERY'].divide(result['TOTAL_CURBSIDE_PICKUP']+result['TOTAL_CURBSIDE_DELIVERY'])
result['CURBSIDE_DELIVERY_%'].fillna(0, inplace=True)

# %%
result['CURBSIDE_DELIVERY_%'].hist()
plt.show()

# %%
curbside_spend_alcohol_tobacco_percentage = "CURBSIDE_SPEND_ALCOHOL_TOBACCO"
curbside_spend_alcohol_tobacco_columns = ["('CURBSIDE_SPEND_TOTAL', 'Beer Wine Liquor')", "('CURBSIDE_SPEND_TOTAL', 'Cigarettes')", "('CURBSIDE_SPEND_TOTAL', 'Tobacco')"]
result[curbside_spend_alcohol_tobacco_percentage] = result[curbside_spend_alcohol_tobacco_columns].sum(axis='columns')
result[curbside_spend_alcohol_tobacco_percentage] = result[curbside_spend_alcohol_tobacco_percentage].divide(result["TOTAL_CURBSIDE_SPEND"])
result[curbside_spend_alcohol_tobacco_percentage] = result[curbside_spend_alcohol_tobacco_percentage].fillna(value=0)

non_curbside_spend_alcohol_tobacco_percentage =  "NON_CURBSIDE_SPEND_ALCOHOL_TOBACCO"
non_curbside_spend_alcohol_tobacco_columns = ["('NON_CURBSIDE_SPEND_TOTAL', 'Beer Wine Liquor')", "('NON_CURBSIDE_SPEND_TOTAL', 'Cigarettes')", "('NON_CURBSIDE_SPEND_TOTAL', 'Tobacco')"]
result[non_curbside_spend_alcohol_tobacco_percentage] = result[non_curbside_spend_alcohol_tobacco_columns].sum(axis='columns')
result[non_curbside_spend_alcohol_tobacco_percentage] = result[non_curbside_spend_alcohol_tobacco_percentage].divide(result["TOTAL_NON_CURBSIDE_SPEND"])
result[non_curbside_spend_alcohol_tobacco_percentage] = result[non_curbside_spend_alcohol_tobacco_percentage].fillna(value=0)

result.head()

# %%
curbside_spend_freshfood_dessert_percentage = "CURBSIDE_SPEND_FRESHFOOD_DESSERT"
curbside_spend_freshfood_dessert_columns = ["('CURBSIDE_SPEND_TOTAL', 'Bakery')", "('CURBSIDE_SPEND_TOTAL', 'Candy')", "('CURBSIDE_SPEND_TOTAL', 'Prepared Foods')"]
result[curbside_spend_freshfood_dessert_percentage] = result[curbside_spend_freshfood_dessert_columns].sum(axis='columns')
result[curbside_spend_freshfood_dessert_percentage] = result[curbside_spend_freshfood_dessert_percentage].divide(result["TOTAL_CURBSIDE_SPEND"])
result[curbside_spend_freshfood_dessert_percentage] = result[curbside_spend_freshfood_dessert_percentage].fillna(value=0)

non_curbside_spend_freshfood_dessert_percentage = "NON_CURBSIDE_SPEND_FRESHFOOD_DESSERT"
non_curbside_spend_freshfood_dessert_columns = ["('NON_CURBSIDE_SPEND_TOTAL', 'Bakery')", "('NON_CURBSIDE_SPEND_TOTAL', 'Candy')", "('NON_CURBSIDE_SPEND_TOTAL', 'Prepared Foods')"]
result[non_curbside_spend_freshfood_dessert_percentage] = result[non_curbside_spend_freshfood_dessert_columns].sum(axis='columns')
result[non_curbside_spend_freshfood_dessert_percentage] = result[non_curbside_spend_freshfood_dessert_percentage].divide(result["TOTAL_NON_CURBSIDE_SPEND"])
result[non_curbside_spend_freshfood_dessert_percentage] = result[non_curbside_spend_freshfood_dessert_percentage].fillna(value=0)

result.head()

# %%
curbside_spend_meat_dairy_percentage = "CURBSIDE_SPEND_MEAT_DAIRY"
curbside_spend_meat_dairy_columns = ["('CURBSIDE_SPEND_TOTAL', 'Seafood')", "('CURBSIDE_SPEND_TOTAL', 'Deli')", "('CURBSIDE_SPEND_TOTAL', 'Meat')", "('CURBSIDE_SPEND_TOTAL', 'Dairy')"]
result[curbside_spend_meat_dairy_percentage] = result[curbside_spend_meat_dairy_columns].sum(axis='columns')
result[curbside_spend_meat_dairy_percentage] = result[curbside_spend_meat_dairy_percentage].divide(result["TOTAL_CURBSIDE_SPEND"])
result[curbside_spend_meat_dairy_percentage] = result[curbside_spend_meat_dairy_percentage].fillna(value=0)

non_curbside_spend_meat_dairy_percentage = "NON_CURBSIDE_SPEND_MEAT_DAIRY"
non_curbside_spend_meat_dairy_columns = ["('NON_CURBSIDE_SPEND_TOTAL', 'Seafood')", "('NON_CURBSIDE_SPEND_TOTAL', 'Deli')", "('NON_CURBSIDE_SPEND_TOTAL', 'Meat')", "('NON_CURBSIDE_SPEND_TOTAL', 'Dairy')"]
result[non_curbside_spend_meat_dairy_percentage] = result[non_curbside_spend_meat_dairy_columns].sum(axis='columns')
result[non_curbside_spend_meat_dairy_percentage] = result[non_curbside_spend_meat_dairy_percentage].divide(result["TOTAL_NON_CURBSIDE_SPEND"])
result[non_curbside_spend_meat_dairy_percentage] = result[non_curbside_spend_meat_dairy_percentage].fillna(value=0)

result.head()

# %%
curbside_spend_household_groceries_percentage = "CURBSIDE_SPEND_HOUSEHOLD_GROCERIES"
curbside_spend_household_groceries_columns = ["('CURBSIDE_SPEND_TOTAL', 'Frozen')", "('CURBSIDE_SPEND_TOTAL', 'Grocery Inedible')", "('CURBSIDE_SPEND_TOTAL', 'HBC')", "('CURBSIDE_SPEND_TOTAL', 'Produce')"]
result[curbside_spend_household_groceries_percentage] = result[curbside_spend_household_groceries_columns].sum(axis='columns')
result[curbside_spend_household_groceries_percentage] = result[curbside_spend_household_groceries_percentage].divide(result["TOTAL_CURBSIDE_SPEND"])
result[curbside_spend_household_groceries_percentage] = result[curbside_spend_household_groceries_percentage].fillna(value=0)

non_curbside_spend_household_groceries_percentage = "NON_CURBSIDE_SPEND_HOUSEHOLD_GROCERIES"
non_curbside_spend_household_groceries_columns = ["('NON_CURBSIDE_SPEND_TOTAL', 'Frozen')", "('NON_CURBSIDE_SPEND_TOTAL', 'Grocery Inedible')", "('NON_CURBSIDE_SPEND_TOTAL', 'HBC')", "('NON_CURBSIDE_SPEND_TOTAL', 'Produce')"]
result[non_curbside_spend_household_groceries_percentage] = result[non_curbside_spend_household_groceries_columns].sum(axis='columns')
result[non_curbside_spend_household_groceries_percentage] = result[non_curbside_spend_household_groceries_percentage].divide(result["TOTAL_NON_CURBSIDE_SPEND"])
result[non_curbside_spend_household_groceries_percentage] = result[non_curbside_spend_household_groceries_percentage].fillna(value=0)

result.head()

# %%
curbside_spend_other_percentage = "CURBSIDE_SPEND_OTHER"
curbside_spend_other_columns = ["('CURBSIDE_SPEND_TOTAL', 'Video')", "('CURBSIDE_SPEND_TOTAL', 'Books & Magazines')", "('CURBSIDE_SPEND_TOTAL', 'Greeting Cards')", "('CURBSIDE_SPEND_TOTAL', 'Miscellaneous')", "('CURBSIDE_SPEND_TOTAL', 'Photo')", "('CURBSIDE_SPEND_TOTAL', 'Frozen')", "('CURBSIDE_SPEND_TOTAL', 'General Merchandise')"]
result[curbside_spend_other_percentage] = result[curbside_spend_other_columns].sum(axis='columns')
result[curbside_spend_other_percentage] = result[curbside_spend_other_percentage].divide(result["TOTAL_CURBSIDE_SPEND"])
result[curbside_spend_other_percentage] = result[curbside_spend_other_percentage].fillna(value=0)

non_curbside_spend_other_percentage = "NON_CURBSIDE_SPEND_OTHER"
non_curbside_spend_other_columns = ["('NON_CURBSIDE_SPEND_TOTAL', 'Video')", "('NON_CURBSIDE_SPEND_TOTAL', 'Books & Magazines')", "('NON_CURBSIDE_SPEND_TOTAL', 'Greeting Cards')", "('NON_CURBSIDE_SPEND_TOTAL', 'Miscellaneous')", "('NON_CURBSIDE_SPEND_TOTAL', 'Photo')", "('NON_CURBSIDE_SPEND_TOTAL', 'Frozen')", "('NON_CURBSIDE_SPEND_TOTAL', 'General Merchandise')"]
result[non_curbside_spend_other_percentage] = result[non_curbside_spend_other_columns].sum(axis='columns')
result[non_curbside_spend_other_percentage] = result[non_curbside_spend_other_percentage].divide(result["TOTAL_NON_CURBSIDE_SPEND"])
result[non_curbside_spend_other_percentage] = result[non_curbside_spend_other_percentage].fillna(value=0)

result.head()

# %%
curbside_spend_grocery_edible_percentage = "CURBSIDE_SPEND_GROCERY_EDIBLE"
curbside_spend_grocery_edible_columns = ["('CURBSIDE_SPEND_TOTAL', 'Grocery Edible')"]
result[curbside_spend_grocery_edible_percentage] = result[curbside_spend_grocery_edible_columns].sum(axis='columns')
result[curbside_spend_grocery_edible_percentage] = result[curbside_spend_grocery_edible_percentage].divide(result["TOTAL_CURBSIDE_SPEND"])
result[curbside_spend_grocery_edible_percentage] = result[curbside_spend_grocery_edible_percentage].fillna(value=0)

non_curbside_spend_grocery_edible_percentage = "NON_CURBSIDE_SPEND_GROCERY_EDIBLE"
non_curbside_spend_grocery_edible_columns = ["('NON_CURBSIDE_SPEND_TOTAL', 'Grocery Edible')"]
result[non_curbside_spend_grocery_edible_percentage] = result[non_curbside_spend_grocery_edible_columns].sum(axis='columns')
result[non_curbside_spend_grocery_edible_percentage] = result[non_curbside_spend_grocery_edible_percentage].divide(result["TOTAL_NON_CURBSIDE_SPEND"])
result[non_curbside_spend_grocery_edible_percentage] = result[non_curbside_spend_grocery_edible_percentage].fillna(value=0)

result.head()

# %%
result.to_csv('/content/drive/My Drive/Giant Eagle/03_Input Data/Clean data/consolidated_household_v05_20191015.csv')
